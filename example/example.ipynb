# %%
from pymodel.qmodel import *

# %%
leaf = Leaf()
leaf.g1 = 13

for PAR in range(50,1500,100):
    print(' PAR=',PAR,Q_model(leaf = leaf,PAR=PAR,RH=0.8,cost = [0.11,0.2,0.00001]))
# Out:
#  PAR= 50 {'An': 0, 'cp': 42.75, 'Ci': 407.28000000000003, 'Vc': 0, 'E': 0, 'gs': 0}
#  PAR= 150 {'An': 6.289089094953517, 'cp': 42.75, 'Ci': 288.9158977342042, 'Vc': 57.180867312307164, 'E': 0.3251063983183806, 'gs': 429.6890559113906}
#  PAR= 250 {'An': 8.315814941993086, 'cp': 42.75, 'Ci': 267.98399654504453, 'Vc': 84.17426526253725, 'E': 0.27690358676209753, 'gs': 637.3225210197792}
#  PAR= 350 {'An': 8.972319979123698, 'cp': 42.75, 'Ci': 259.813363508953, 'Vc': 95.8462371779939, 'E': 0.22186446054371275, 'gs': 727.44940081616}
#  PAR= 450 {'An': 9.277921143718952, 'cp': 42.75, 'Ci': 255.46611184367202, 'Vc': 102.35707239702879, 'E': 0.1827836348654523, 'gs': 777.7518318525871}
#  PAR= 550 {'An': 9.44968518219996, 'cp': 42.75, 'Ci': 252.76863066140618, 'Vc': 106.50966338267035, 'E': 0.1548193830345236, 'gs': 809.8345329440243}
#  PAR= 650 {'An': 9.558058950611292, 'cp': 42.75, 'Ci': 250.93193040904157, 'Vc': 109.38859146681304, 'E': 0.13406748158734222, 'gs': 832.0741936647811}
#  PAR= 750 {'An': 9.631986092644757, 'cp': 42.75, 'Ci': 249.60081457409828, 'Vc': 111.50183381490429, 'E': 0.11813172045267478, 'gs': 848.3965516661372}
#  PAR= 850 {'An': 9.68532475966859, 'cp': 42.75, 'Ci': 248.59183722403458, 'Vc': 113.11896342367822, 'E': 0.10553829578707798, 'gs': 860.8852601997689}
#  PAR= 950 {'An': 9.72546666511979, 'cp': 42.75, 'Ci': 247.800707473054, 'Vc': 114.39631221127715, 'E': 0.0953479529799376, 'gs': 870.7486747387218}
#  PAR= 1050 {'An': 9.756684744528552, 'cp': 42.75, 'Ci': 247.16375996208245, 'Vc': 115.43077793155545, 'E': 0.08693882843876333, 'gs': 878.7357041713962}
#  PAR= 1150 {'An': 9.781607952376438, 'cp': 42.75, 'Ci': 246.63993147000437, 'Vc': 116.28561538541939, 'E': 0.07988463205539223, 'gs': 885.3351870696721}
#  PAR= 1250 {'An': 9.801936280063876, 'cp': 42.75, 'Ci': 246.2015496706535, 'Vc': 117.0038704624377, 'E': 0.0738841031989357, 'gs': 890.8797499978962}
#  PAR= 1350 {'An': 9.818814596472123, 'cp': 42.75, 'Ci': 245.82928665832907, 'Vc': 117.61585331379511, 'E': 0.06871863464637885, 'gs': 895.603582167442}
#  PAR= 1450 {'An': 9.833040429637487, 'cp': 42.75, 'Ci': 245.5092344789158, 'Vc': 118.14352379128111, 'E': 0.06422590704645148, 'gs': 899.6763374068842}

# %%
# Tleaf	CO2R	CO2S	H2OS	Flow	PARi	Press
# 30.23	415.66	394.51	25.807	350.6	1800	101.5
for t in range(-10,40,5):
    print(' t=',t,Q_model(leaf = leaf,tleaf=t,PAR=1500,RH=0.4,cost = [0.11,0.8,0.00001]))
# Out:
#  t= -10 {'An': 0.4803142680445076, 'cp': 42.75, 'Ci': 275.46712752298583, 'Vc': 8.504531507953944, 'E': 0.004725329151522151, 'gs': 26.27661486265867}
#  t= -5 {'An': 0.7465258113846756, 'cp': 42.75, 'Ci': 272.3206931145363, 'Vc': 12.755974010567, 'E': 0.007048286480532515, 'gs': 39.454844237627135}
#  t= 0 {'An': 1.0582751129575863, 'cp': 42.75, 'Ci': 268.933397329018, 'Vc': 17.434792605721395, 'E': 0.009575418788948655, 'gs': 53.986548259074624}
#  t= 5 {'An': 1.4285055871130916, 'cp': 42.75, 'Ci': 265.24053189384244, 'Vc': 22.661638227171963, 'E': 0.012363086914308047, 'gs': 70.25205725357749}
#  t= 10 {'An': 1.877279305192717, 'cp': 42.75, 'Ci': 261.14255041571465, 'Vc': 28.62354743760237, 'E': 0.015498365023598762, 'gs': 88.84042533140827}
#  t= 15 {'An': 2.4387178385453234, 'cp': 42.75, 'Ci': 256.4714679290314, 'Vc': 35.638734086148034, 'E': 0.01912886045186978, 'gs': 110.7528099152227}
#  t= 20 {'An': 3.180083141128188, 'cp': 42.75, 'Ci': 250.8988866631297, 'Vc': 44.33480557479951, 'E': 0.02354456230853977, 'gs': 137.961486768125}
#  t= 25 {'An': 4.277116701467242, 'cp': 42.75, 'Ci': 243.5745601333916, 'Vc': 56.35291625165474, 'E': 0.02950047060562515, 'gs': 175.61676321179812}
#  t= 30 {'An': 7.616053243175003, 'cp': 42.75, 'Ci': 225.50622606569237, 'Vc': 89.34256023196092, 'E': 0.045057145879798643, 'gs': 278.96818407850407}
#  t= 35 {'An': 4.277116701467242, 'cp': 42.75, 'Ci': 243.5745601333916, 'Vc': 56.35291625165474, 'E': 0.02950047060562515, 'gs': 175.61676321179812}
